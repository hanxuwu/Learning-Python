# %%
class Tree:
    def __init__(self, value = None):
        self.value = value
        self.left = None
        self.right = None
        
T = Tree()
print(T.value, T.left, T.right)
T = Tree(2)
print(T.value, T.left, T.right)

# %%
class Tree:
    def __init__(self, value = None):
        self.value = value
        if value is None:
            self.left = None
            self.right = None
        else:
            self.left = Tree()
            self.right = Tree()
        
T = Tree(2)
print(T.value, T.left, T.right)
print(T.value, T.left.value, T.right.value, T.left.left, T.left.right)

# %%
class Tree:
    def __init__(self, value = None):
        self.value = value
        if value is None:
            self.left = None
            self.right = None
        else:
            self.left = Tree()
            self.right = Tree()
        
T = Tree('+')
T.left = Tree(2)
T1 = Tree('*')
T.right = T1
T1.left = Tree(3)
T1.right = Tree(4)

def evaluate(expression_tree):
    if expression_tree.value is None:
        return
    if isinstance(expression_tree.value, int):
        return expression_tree.value
    if expression_tree.value == '+':
        return evaluate(expression_tree.left) +\
                               evaluate(expression_tree.right) 
    if expression_tree.value == '*':
        return evaluate(expression_tree.left) *\
                               evaluate(expression_tree.right)

evaluate(T)

# %%
class Tree:
    def __init__(self, value = None):
        self.value = value
        if value is None:
            self.left = None
            self.right = None
        else:
            self.left = Tree()
            self.right = Tree()
            
    def height(self):
        if self.value is None:
            return 0
        return max(self.left._height(), self.right._height())
    
    def _height(self):
        if self.value is None:
            return 0
        return 1 + max(self.left._height(), self.right._height())
                       
print(Tree().height())
print(Tree(2).height())
T = Tree(2)
T1 = Tree(4)
T.right = T1
print(T.height())
T2 = Tree(6)
T3 = Tree(7)
T4 = Tree(8)
T.left = T4
T1.left = T2
T1.right = T3
print(T.height())

# %%
class Tree:
    def __init__(self, value = None):
        self.value = value
        if value is None:
            self.left = None
            self.right = None
        else:
            self.left = Tree()
            self.right = Tree()
            
    def height(self):
        if self.value is None:
            return 0
        return max(self.left._height(), self.right._height())
    
    def _height(self):
        if self.value is None:
            return 0
        return 1 + max(self.left._height(), self.right._height())
    
    def print_tree(self):
        self._print_tree(0, self.height())
        
    def _print_tree(self, depth, height):
        if self.value is not None:
            self.left._print_tree(depth + 1, height)
            print('    ' * depth, self.value, sep = '')
            self.right._print_tree(depth + 1, height)
        else:
            print('\n' * (2 **(height - depth + 1) - 1))

                       
#Tree().print_tree()
#Tree(2).print_tree()
T = Tree(1)
T1 = Tree(0)
T2 = Tree(2)
T3 = Tree(3)
T4 = Tree(4)
T.left = T1
T.right = T2
T2.left = T3
T2.right = T4
T.print_tree()

# %%
class Tree:
    def __init__(self, value = None):
        self.value = value
        if value is None:
            self.left = None
            self.right = None
        else:
            self.left = Tree()
            self.right = Tree()
            
    def height(self):
        if self.value is None:
            return 0
        return max(self.left._height(), self.right._height())
    
    def _height(self):
        if self.value is None:
            return 0
        return 1 + max(self.left._height(), self.right._height())
    
    def print_tree(self):
        self._print_tree(0, self.height())
        
    def _print_tree(self, depth, height):
        if self.value is not None:
            self.left._print_tree(depth + 1, height)
            print('    ' * depth, self.value, sep = '')
            self.right._print_tree(depth + 1, height)
        else:
            print('\n' * (2 **(height - depth + 1) - 1))
            
    def is_bst(self):
        if self.value is None:
            return True
        if self.left.value is not None:
            tree_on_left = self.left
            while tree_on_left.right.value is not None:
                tree_on_left = tree_on_left.right
            if self.value <= tree_on_left.value:
                return False
        if self.right.value is not None:
            tree_on_right = self.right
            while tree_on_right.left.value is not None:
                tree_on_right = tree_on_right.left
            if self.value <= tree_on_right.value:
                return False

        return self.left.is_bst() and self.right.is_bst()


                       
T = Tree(1)
T1 = Tree(0)
T2 = Tree(3)
T3 = Tree(-1)
T4 = Tree(4)
T.left = T1
T.right = T2
T2.left = T3
T2.right = T4
T.print_tree()
T.is_bst()

# %%
class Tree:
    def __init__(self, value = None):
        self.value = value
        if value is None:
            self.left = None
            self.right = None
        else:
            self.left = Tree()
            self.right = Tree()
            
    def height(self):
        if self.value is None:
            return 0
        return max(self.left._height(), self.right._height())
    
    def _height(self):
        if self.value is None:
            return 0
        return 1 + max(self.left._height(), self.right._height())
    
    def print_tree(self):
        self._print_tree(0, self.height())
        
    def _print_tree(self, depth, height):
        if self.value is not None:
            self.left._print_tree(depth + 1, height)
            print('    ' * depth, self.value, sep = '')
            self.right._print_tree(depth + 1, height)
        else:
            print('\n' * (2 **(height - depth + 1) - 1))
            
    def is_bst(self):
        if self.value is None:
            return True
        if self.left.value is not None:
            tree_on_left = self.left
            while tree_on_left.right.value is not None:
                tree_on_left = tree_on_left.right
            if self.value <= tree_on_left.value:
                return False
        if self.right.value is not None:
            tree_on_right = self.right
            while tree_on_right.left.value is not None:
                tree_on_right = tree_on_right.left
            if self.value <= tree_on_right.value:
                return False
        return self.left.is_bst() and self.right.is_bst()
    
    def insert_in_bst(self, value):
        if self.value is None:
            self.value = value
            self.left = Tree()
            self.right = Tree()
            return True
        if self.value is value:
            return False
        if self.value > value:
            return self.left.insert_in_bst(value)
        return self.right.insert_in_bst(value)
    
T = Tree()
for e in 7, 1, 8, 10, 4, 6, 2, 5:
    T.insert_in_bst(e)
T.print_tree()

# %%
class Tree:
    def __init__(self, value = None):
        self.value = value
        if value is None:
            self.left = None
            self.right = None
        else:
            self.left = Tree()
            self.right = Tree()
            
    def height(self):
        if self.value is None:
            return 0
        return max(self.left._height(), self.right._height())
    
    def _height(self):
        if self.value is None:
            return 0
        return 1 + max(self.left._height(), self.right._height())
    
    def print_tree(self):
        self._print_tree(0, self.height())
        
    def _print_tree(self, depth, height):
        if self.value is not None:
            self.left._print_tree(depth + 1, height)
            print('    ' * depth, self.value, sep = '')
            self.right._print_tree(depth + 1, height)
        else:
            print('\n' * (2 **(height - depth + 1) - 1))
            
    def is_bst(self):
        if self.value is None:
            return True
        if self.left.value is not None:
            tree_on_left = self.left
            while tree_on_left.right.value is not None:
                tree_on_left = tree_on_left.right
            if self.value <= tree_on_left.value:
                return False
        if self.right.value is not None:
            tree_on_right = self.right
            while tree_on_right.left.value is not None:
                tree_on_right = tree_on_right.left
            if self.value <= tree_on_right.value:
                return False
        return self.left.is_bst() and self.right.is_bst()
    
    def insert_in_bst(self, value):
        if self.value is None:
            self.value = value
            self.left = Tree()
            self.right = Tree()
            return True
        if self.value is value:
            return False
        if self.value > value:
            return self.left.insert_in_bst(value)
        return self.right.insert_in_bst(value)
    
T = Tree()
for e in 7, 1, 8, 10, 4, 6, 2, 5:
    T.insert_in_bst(e)
T.print_tree()

# %%
class Tree:
    def __init__(self, value = None):
        self.value = value
        if value is None:
            self.left = None
            self.right = None
        else:
            self.left = Tree()
            self.right = Tree()
            
    def height(self):
        if self.value is None:
            return 0
        return max(self.left._height(), self.right._height())
    
    def _height(self):
        if self.value is None:
            return 0
        return 1 + max(self.left._height(), self.right._height())
    
    def print_tree(self):
        self._print_tree(0, self.height())
        
    def _print_tree(self, depth, height):
        if self.value is not None:
            self.left._print_tree(depth + 1, height)
            print('    ' * depth, self.value, sep = '')
            self.right._print_tree(depth + 1, height)
        else:
            print('\n' * (2 **(height - depth + 1) - 1))
            
    def is_bst(self):
        if self.value is None:
            return True
        if self.left.value is not None:
            tree_on_left = self.left
            while tree_on_left.right.value is not None:
                tree_on_left = tree_on_left.right
            if self.value <= tree_on_left.value:
                return False
        if self.right.value is not None:
            tree_on_right = self.right
            while tree_on_right.left.value is not None:
                tree_on_right = tree_on_right.left
            if self.value <= tree_on_right.value:
                return False
        return self.left.is_bst() and self.right.is_bst()
    
    def insert_in_bst(self, value):
        if self.value is None:
            self.value = value
            self.left = Tree()
            self.right = Tree()
            return True
        if self.value is value:
            return False
        if self.value > value:
            return self.left.insert_in_bst(value)
        return self.right.insert_in_bst(value)
    
    def explore_in_order(self):
        if self.value is None:
            return
        self.left.explore_in_order()
        print(self.value, end = ' ')
        self.right.explore_in_order()

    def explore_post_order(self):
        if self.value is None:
            return
        self.left.explore_post_order()
        self.right.explore_post_order()
        print(self.value, end = ' ')


T = Tree()
for e in 7, 1, 8, 10, 4, 6, 2, 5:
    T.insert_in_bst(e)

T.explore_in_order()
print()
T.explore_post_order()
# Out:
# 1 2 4 5 6 7 8 10
# 2 5 6 4 1 10 8 7
